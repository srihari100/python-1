# %%
l = [1,2,3,4.5,"gayatri",45]
print(l)
# Out:
# [1, 2, 3, 4.5, 'gayatri', 45]

# %%
l[2]
# Out:
# 3

# %%
for i in l:
    print(i)
# Out:
# 1
# 2
# 3
# 4.5
# gayatri
# 45

# %%
l.append(45)

# %%
print(l)
# Out:
# [1, 2, 3, 4.5, 'gayatri', 45]

# %%
l2=["vidya",23]
l.extend(l2)

# %%
l
# Out:
# [1, 2, 3, 4.5, 'gayatri', 45, 45, 'vidya', 23]

# %%
l.insert(4,"welcome")

# %%
l
# Out:
# ['welcome',
#  'l',
#  [...],
#  1,
#  'welcome',
#  2,
#  3,
#  4.5,
#  'gayatri',
#  45,
#  45,
#  'vidya',
#  23]

# %%
l.remove('gayatri')

# %%
l
# Out:
# ['welcome', 'l', [...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya', 23]

# %%
l.remove('l')

# %%
l
# Out:
# ['welcome', [...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya', 23]

# %%
l.pop()
# Out:
# 23

# %%
l
# Out:
# ['welcome', [...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya']

# %%
l.pop(0)
# Out:
# 'welcome'

# %%
l
# Out:
# [[...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya']

# %%
l.index(2)
# Out:
# 3

# %%
l
# Out:
# [[...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya']

# %%
a=[1,2,3,2,5,5,7,2]
a.count(2)
# Out:
# 3

# %%
a
# Out:
# [1, 2, 3, 2, 5, 5, 7, 2]

# %%
a.sort()

# %%
a
# Out:
# [1, 2, 2, 2, 3, 5, 5, 7]

# %%
a.reverse()

# %%
a
# Out:
# [7, 5, 5, 3, 2, 2, 2, 1]

# %%
sorted(a,reverse=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-37-150a3a75508f> in <module>
# ----> 1 sorted(a,reverse=true)
#
# NameError: name 'true' is not defined

# %%
l
# Out:
# [[...], 1, 'welcome', 2, 3, 4.5, 45, 45, 'vidya']

# %%
a
# Out:
# [7, 5, 5, 3, 2, 2, 2, 1]

# %%
sorted(a,reverse=false)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-776d5327bead> in <module>
# ----> 1 sorted(a,reverse=false)
#
# NameError: name 'false' is not defined

# %%
a
# Out:
# [7, 5, 5, 3, 2, 2, 2, 1]

# %%
help(list)
# Out:
# Help on class list in module builtins:
#
# class list(object)
#  |  list(iterable=(), /)
#  |
#  |  Built-in mutable sequence.
#  |
#  |  If no argument is given, the constructor creates a new empty list.
#  |  The argument must be an iterable if specified.
#  |
#  |  Methods defined here:
#  |
#  |  __add__(self, value, /)
#  |      Return self+value.
#  |
#  |  __contains__(self, key, /)
#  |      Return key in self.
#  |
#  |  __delitem__(self, key, /)
#  |      Delete self[key].
#  |
#  |  __eq__(self, value, /)
#  |      Return self==value.
#  |
#  |  __ge__(self, value, /)
#  |      Return self>=value.
#  |
#  |  __getattribute__(self, name, /)
#  |      Return getattr(self, name).
#  |
#  |  __getitem__(...)
#  |      x.__getitem__(y) <==> x[y]
#  |
#  |  __gt__(self, value, /)
#  |      Return self>value.
#  |
#  |  __iadd__(self, value, /)
#  |      Implement self+=value.
#  |
#  |  __imul__(self, value, /)
#  |      Implement self*=value.
#  |
# ...

# %%
l = [ 1,2,34,5,6,7,99,0,34,90]
s=0
for i in l:
    s=s+i
print(s)
# Out:
# 278

# %%
n=int(input('enter the number of numbers '))
i=0
while i<=n:
    l[n]=int(input())
    i=i+1
s=0
for i in l:
    s=s+i
print(s)
# Out:
# enter the number of numbers 5
# 1
# 2
# 3
# 4
# 5
# 5
# 535

# %%
l=[1233456789]
l
# Out:
# [1233456789]

# %%
l.insert(2,",")
l
# Out:
# [1233456789, ',', ',', ',', ',', ',']

# %%
num=int(input())
i=0
while i<=num-1:
    l[i]=int(input())
    i=i+1
i=0    
while i<=num-1:
    print(l[i],end=",")
    i=i+1
# Out:
# 3
# 1
# 2
# 3
# 1,2,3,
